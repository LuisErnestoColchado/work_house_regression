# %%
import pandas as pd 
from xgboost.sklearn import XGBClassifier  
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import numpy as np # linear algebra
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # Reading Data

# %%
trainData = pd.read_csv('all/train.csv',index_col=0)
testData = pd.read_csv('all/test.csv',index_col=0)
submissionData = pd.read_csv('all/sample_submission.csv',index_col=0);
trainData['MSSubClass'].head()
# Out:
# Id
# 1    60
# 2    20
# 3    60
# 4    70
# 5    60
# Name: MSSubClass, dtype: int64

# %%
trainData.shape
# Out:
# (1460, 80)

# %%
testData.shape
# Out:
# (1459, 79)

# %% [markdown]
# # Preparing Data

# %%
trainData.tail()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1456         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1457         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1458         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1459         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1460         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1456       Norm     1Fam     2Story            6            5       1999
# 1457       Norm     1Fam     1Story            6            6       1978
# 1458       Norm     1Fam     2Story            7            9       1941
# 1459       Norm     1Fam     1Story            5            6       1950
# 1460       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1456          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1457          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1458          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1459          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1460          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1456         0.0        TA        TA      PConc       Gd       TA
# 1457       119.0        TA        TA     CBlock       Gd       TA
# 1458         0.0        Ex        Gd      Stone       TA       Gd
# 1459         0.0        TA        TA     CBlock       TA       TA
# 1460         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1456           No          Unf           0          Unf           0
# 1457           No          ALQ         790          Rec         163
# 1458           No          GLQ         275          Unf           0
# 1459           Mn          GLQ          49          Rec        1029
# 1460           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1456        953          953    GasA        Ex          Y      SBrkr
# 1457        589         1542    GasA        TA          Y      SBrkr
# 1458        877         1152    GasA        Ex          Y      SBrkr
# 1459          0         1078    GasA        Gd          Y      FuseA
# 1460        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1456       953       694             0       1647             0             0
# 1457      2073         0             0       2073             1             0
# 1458      1188      1152             0       2340             0             0
# 1459      1078         0             0       1078             1             0
# 1460      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1456         2         1             3             1          TA
# 1457         2         0             3             1          TA
# 1458         2         0             4             1          Gd
# 1459         1         0             2             1          Gd
# 1460         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1456             7        Typ           1          TA     Attchd       1999.0
# 1457             7       Min1           2          TA     Attchd       1978.0
# 1458             9        Typ           2          Gd     Attchd       1941.0
# 1459             5        Typ           0         NaN     Attchd       1950.0
# 1460             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1456          RFn           2         460         TA         TA          Y
# 1457          Unf           2         500         TA         TA          Y
# 1458          RFn           1         252         TA         TA          Y
# 1459          Unf           1         240         TA         TA          Y
# 1460          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1456           0           40              0          0            0
# 1457         349            0              0          0            0
# 1458           0           60              0          0            0
# 1459         366            0            112          0            0
# 1460         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1456         0    NaN    NaN         NaN        0       8    2007       WD
# 1457         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1458         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1459         0    NaN    NaN         NaN        0       4    2010       WD
# 1460         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# Id
# 1456        Normal     175000
# 1457        Normal     210000
# 1458        Normal     266500
# 1459        Normal     142125
# 1460        Normal     147500

# %%
allDataNa = (trainData.isnull().sum() / len(trainData)) * 100
allDataNa = allDataNa.drop(allDataNa[allDataNa == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :allDataNa})
missing_data.head(20)
# Out:
#               Missing Ratio
# PoolQC            99.520548
# MiscFeature       96.301370
# Alley             93.767123
# Fence             80.753425
# FireplaceQu       47.260274
# LotFrontage       17.739726
# GarageYrBlt        5.547945
# GarageType         5.547945
# GarageFinish       5.547945
# GarageQual         5.547945
# GarageCond         5.547945
# BsmtFinType2       2.602740
# BsmtExposure       2.602740
# BsmtFinType1       2.534247
# BsmtCond           2.534247
# BsmtQual           2.534247
# MasVnrArea         0.547945
# MasVnrType         0.547945
# Electrical         0.068493

# %% [markdown]
# ## Remove the columns ['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'], because they have more 20% of null values

# %%
columns = ['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'] 
trainData.drop(columns,inplace=True,axis=1)
testData.drop(columns,inplace=True,axis=1)

# %%
trainData.shape
# Out:
# (1460, 75)

# %%
testData.shape
# Out:
# (1459, 74)

# %%
trainData.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Correlation Data

# %%
corrmat = trainData.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)

# %%
trainData.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1           60       RL         65.0     8450   Pave      Reg         Lvl
# 2           20       RL         80.0     9600   Pave      Reg         Lvl
# 3           60       RL         68.0    11250   Pave      IR1         Lvl
# 4           70       RL         60.0     9550   Pave      IR1         Lvl
# 5           60       RL         84.0    14260   Pave      IR1         Lvl
#
#    Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# Id
# 1     AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 2     AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 3     AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 4     AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 5     AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# Id
# 1      2Story            7            5       2003          2003     Gable
# 2      1Story            6            8       1976          1976     Gable
# 3      2Story            7            5       2001          2002     Gable
# 4      2Story            7            5       1915          1970     Gable
# 5      2Story            8            5       2000          2000     Gable
#
#    RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# Id
# 1   CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd
# 2   CompShg     MetalSd     MetalSd       None         0.0        TA
# 3   CompShg     VinylSd     VinylSd    BrkFace       162.0        Gd
# 4   CompShg     Wd Sdng     Wd Shng       None         0.0        TA
# 5   CompShg     VinylSd     VinylSd    BrkFace       350.0        Gd
#
#    ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# Id
# 1         TA      PConc       Gd       TA           No          GLQ
# 2         TA     CBlock       Gd       TA           Gd          ALQ
# 3         TA      PConc       Gd       TA           Mn          GLQ
# 4         TA     BrkTil       TA       Gd           No          ALQ
# 5         TA      PConc       Gd       TA           Av          GLQ
#
#     BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# Id
# 1          706          Unf           0        150          856    GasA
# 2          978          Unf           0        284         1262    GasA
# 3          486          Unf           0        434          920    GasA
# 4          216          Unf           0        540          756    GasA
# 5          655          Unf           0        490         1145    GasA
#
#    HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1         Ex          Y      SBrkr       856       854             0
# 2         Ex          Y      SBrkr      1262         0             0
# 3         Ex          Y      SBrkr       920       866             0
# 4         Gd          Y      SBrkr       961       756             0
# 5         Ex          Y      SBrkr      1145      1053             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1        1710             1             0         2         1             3
# 2        1262             0             1         2         0             3
# 3        1786             1             0         2         1             3
# 4        1717             1             0         1         0             3
# 5        2198             1             0         2         1             4
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces GarageType  \
# Id
# 1              1          Gd             8        Typ           0     Attchd
# 2              1          TA             6        Typ           1     Attchd
# 3              1          Gd             6        Typ           1     Attchd
# 4              1          Gd             7        Typ           1     Detchd
# 5              1          Gd             9        Typ           1     Attchd
#
#     GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# Id
# 1        2003.0          RFn           2         548         TA         TA
# 2        1976.0          RFn           2         460         TA         TA
# 3        2001.0          RFn           2         608         TA         TA
# 4        1998.0          Unf           3         642         TA         TA
# 5        2000.0          RFn           3         836         TA         TA
#
#    PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1           Y           0           61              0          0            0
# 2           Y         298            0              0          0            0
# 3           Y           0           42              0          0            0
# 4           Y           0           35            272          0            0
# 5           Y         192           84              0          0            0
#
#     PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# 1          0        0       2    2008       WD        Normal     208500
# 2          0        0       5    2007       WD        Normal     181500
# 3          0        0       9    2008       WD        Normal     223500
# 4          0        0       2    2006       WD       Abnorml     140000
# 5          0        0      12    2008       WD        Normal     250000

# %% [markdown]
# ## Convert Categorical Data

# %%
categoricalColumns = ['BldgType','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','BsmtQual','CentralAir',
                      'Condition1','Condition2','Electrical','ExterCond','ExterQual','Exterior1st','Exterior2nd', 
                      'Foundation','Functional','GarageCond','GarageFinish','GarageQual','GarageType',
                      'Heating','HeatingQC','HouseStyle', 'KitchenQual','LandContour','LandSlope','LotConfig','LotShape',
                      'MSZoning','MasVnrType','Neighborhood','PavedDrive','RoofMatl','RoofStyle','SaleCondition','SaleType',
                      'Street','Utilities']
trainData = trainData.fillna("none")
testData = testData.fillna("none")
le = preprocessing.LabelEncoder()
trainData.dtypes
for column in categoricalColumns:
    print(column)
    le.fit(trainData[column])
    trainData[column] = le.fit_transform(trainData[column])
    le.fit(testData[column])
    testData[column] = le.fit_transform(testData[column])
trainData.replace('none', 0,inplace=True)
testData.replace('none', 0,inplace=True)
trainData.head()
testData.head()
# Out:
# BldgType
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# BsmtQual
# CentralAir
# Condition1
# Condition2
# Electrical
# ExterCond
# ExterQual
# Exterior1st
# Exterior2nd
# Foundation
# Functional
# GarageCond
# GarageFinish
# GarageQual
# GarageType
# Heating
# HeatingQC
# HouseStyle
# KitchenQual
# LandContour
# LandSlope
# LotConfig
# LotShape
# MSZoning
# MasVnrType
# Neighborhood
# PavedDrive
# RoofMatl
# RoofStyle
# SaleCondition
# SaleType
# Street
# Utilities
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# Id
# 1461          20         2         80.0    11622       1         3
# 1462          20         3         81.0    14267       1         0
# 1463          60         3         74.0    13830       1         0
# 1464          60         3         78.0     9978       1         0
# 1465         120         3         43.0     5005       1         0
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# Id
# 1461            3          0          4          0            12           1
# 1462            3          0          0          0            12           2
# 1463            3          0          4          0             8           2
# 1464            3          0          4          0             8           2
# 1465            1          0          4          0            22           2
#
#       Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461           2         0           2            5            6       1961
# 1462           2         0           2            6            6       1958
# 1463           2         0           4            5            5       1997
# 1464           2         0           4            6            6       1998
# 1465           2         4           2            8            5       1992
#
#       YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# Id
# 1461          1961          1         0           10           12           2
# 1462          1958          3         0           11           13           1
# 1463          1998          1         0           10           12           2
# 1464          1998          1         0           10           12           1
# 1465          1992          1         0            6            6           2
#
#       MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# Id
# 1461         0.0          3          4           1         3         3
# 1462       108.0          3          4           1         3         3
# 1463         0.0          3          4           2         2         3
# 1464        20.0          3          4           2         3         3
# 1465         0.0          2          4           2         2         3
#
#       BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# Id
# 1461             3             4       468.0             3       144.0
# 1462             3             0       923.0             5         0.0
# 1463             3             2       791.0             5         0.0
# 1464             3             2       602.0             5         0.0
# 1465             3             0       263.0             5         0.0
#
#       BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# Id
# 1461      270.0        882.0        0          4           1           3
# 1462      406.0       1329.0        0          4           1           3
# 1463      137.0        928.0        0          2           1           3
# 1464      324.0        926.0        0          0           1           3
# 1465     1017.0       1280.0        0          0           1           3
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# Id
# 1461         1         0             2             1            3
# 1462         1         1             3             1            2
# 1463         2         1             3             1            3
# 1464         2         1             3             1            2
# 1465         2         0             2             1            2
#
#       TotRmsAbvGrd  Functional  Fireplaces  GarageType  GarageYrBlt  \
# Id
# 1461             5           6           0           1       1961.0
# 1462             6           6           0           1       1958.0
# 1463             6           6           1           1       1997.0
# 1464             7           6           1           1       1998.0
# 1465             5           6           0           1       1992.0
#
#       GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  \
# Id
# 1461             2         1.0       730.0           3           4
# 1462             2         1.0       312.0           3           4
# 1463             0         2.0       482.0           3           4
# 1464             0         2.0       470.0           3           4
# 1465             1         2.0       506.0           3           4
#
#       PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1461           2         140            0              0          0
# 1462           2         393           36              0          0
# 1463           2         212           34              0          0
# 1464           2         360           36              0          0
# 1465           2           0           82              0          0
#
#       ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461          120         0        0       6    2010         8              4
# 1462            0         0    12500       6    2010         8              4
# 1463            0         0        0       3    2010         8              4
# 1464            0         0        0       6    2010         8              4
# 1465          144         0        0       1    2010         8              4

# %%
trainData.shape
# Out:
# (1460, 75)

# %%
trainData.insert(0, "bias", 1)

# %% [markdown]
# # Models

# %% [markdown]
# ## Define of Random Forest and My Linear Regression Models

# %%
xgregr = XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
regr = RandomForestRegressor(max_depth=2, random_state=0,n_estimators=200)
features = trainData.columns[:74]

# %%
#Define Random Forest 
def RandomForest(pTrain,pYTrain,pTest,pYTest):
    regr.fit(pTrain, pYTrain)
    predict = regr.predict(pTest)
    #errorRF = mean_squared_error(pYTest,predict)
    errorRF=np.sqrt(np.mean((np.log(1+predict) - np.log(1+pYTest))**2))
    print("Error of Random Forest model: ", errorRF)
    
#Define XGBOOST
def xgboost(pTrain,pYTrain,pTest,pYTest):
    xgregr.fit(pTrain, pYTrain)  
    predict = xgregr.predict(pTest)
    #errorXGB = mean_squared_error(pYTest,predict)
    errorXGB=np.sqrt(np.mean((np.log(1+predict) - np.log(1+pYTest))**2))
    print("Error of XGBOOST model: ", errorXGB)
    
#Define My Linear Regression 
def MyLinearRegression(pTrain,pYTrain,pTest,pYTest,cross):
    alfa = np.power(10.0,-15.0)
    parameters = 2 * np.random.random_sample((len(features)+1,1)) 
    print(pTrain.shape)
    sum = 0
    count = 0
    cycle = 240000
    while(count < cycle):
        h = np.matmul(pTrain,parameters)
        error1 = pYTrain - h
        derivate = np.matmul(error1.T,pTrain)
        parameters = parameters + (alfa * derivate.T)
        powError = error1[0] ** 2
        cycleError = powError.sum()
        cost = 1.0/pTrain.shape[0] * cycleError
        count= count + 1
        if(cross == 1 and count == 180000):
            global mrlWeight
            mrlWeight = parameters 
            print("Get the best parameters")
        if(count % 10000 == 0):    
            hTest = np.matmul(pTest,parameters)
            err_ep=np.sqrt(np.mean((np.log(1+hTest) - np.log(1+pYTest))**2))
            print("iteracion ", count)
            print("error of My Linear Regression ", err_ep)

# %% [markdown]
# ## Cross Validation

# %%
### Cross validation 
kFolds = KFold(n_splits=5)
npTrainData = trainData.values
countCross = 1 
for train, test in kFolds.split(npTrainData):
    trainD = npTrainData[train,0:75]
    testD = npTrainData[test,0:75]
    yTrain = npTrainData[train,75:76]
    yTest = npTrainData[test,75:76]
    print("------------- CROSS VALIDATION ",countCross,"---------")
    print("------------- Random Forest ---------")
    RandomForest(trainD,yTrain.ravel(),testD,yTest.ravel())
    print("------------- XGBOOST ---------")
    xgboost(trainD,yTrain.ravel(),testD,yTest.ravel())
    print("------------- My Linear Regression ---------")
    MyLinearRegression(trainD,yTrain,testD,yTest,countCross)
    countCross = countCross + 1
# Out:
# ------------- CROSS VALIDATION  1 ---------
# ------------- Random Forest ---------
# Error of Random Forest model:  0.24395733220904828
# ------------- XGBOOST ---------
# Error of XGBOOST model:  0.11932953018380113
# ------------- My Linear Regression ---------
# (1168, 75)
# iteracion  10000
# error of My Linear Regression  0.5846582322904744
# iteracion  20000
# error of My Linear Regression  0.47945336020401913
# iteracion  30000
# error of My Linear Regression  0.42960280114627997
# iteracion  40000
# error of My Linear Regression  0.39319195861094036
# iteracion  50000
# error of My Linear Regression  0.36533322014279856
# iteracion  60000
# error of My Linear Regression  0.34401332334624235
# iteracion  70000
# error of My Linear Regression  0.32780698270477454
# iteracion  80000
# error of My Linear Regression  0.31560330383918517
# iteracion  90000
# error of My Linear Regression  0.3065182559845159
# iteracion  100000
# error of My Linear Regression  0.29984572530204245
# iteracion  110000
# error of My Linear Regression  0.2950237424650763
# iteracion  120000
# error of My Linear Regression  0.2916081669283616
# iteracion  130000
# error of My Linear Regression  0.2892508054082824
# iteracion  140000
# error of My Linear Regression  0.2876808546841391
# iteracion  150000
# error of My Linear Regression  0.28668925396570083
# iteracion  160000
# error of My Linear Regression  0.28611569786240915
# iteracion  170000
# error of My Linear Regression  0.28583804568582366
# Get the best parameters
# iteracion  180000
# error of My Linear Regression  0.2857638205051972
# iteracion  190000
# error of My Linear Regression  0.28582347308729417
# iteracion  200000
# error of My Linear Regression  0.28596509704456813
# iteracion  210000
# error of My Linear Regression  0.2861503127974607
# iteracion  220000
# error of My Linear Regression  0.2863510785124241
# iteracion  230000
# error of My Linear Regression  0.2865472281024643
# iteracion  240000
# error of My Linear Regression  0.28672457510299765
# ------------- CROSS VALIDATION  2 ---------
# ------------- Random Forest ---------
# Error of Random Forest model:  0.2617772504238753
# ------------- XGBOOST ---------
# Error of XGBOOST model:  0.14479125964854364
# ------------- My Linear Regression ---------
# (1168, 75)
# iteracion  10000
# error of My Linear Regression  0.5414051392675974
# iteracion  20000
# error of My Linear Regression  0.4687345964762672
# iteracion  30000
# error of My Linear Regression  0.44291480262234134
# iteracion  40000
# error of My Linear Regression  0.4243736371637103
# iteracion  50000
# error of My Linear Regression  0.4092691065809601
# iteracion  60000
# error of My Linear Regression  0.3967039750479075
# iteracion  70000
# error of My Linear Regression  0.38618890607888245
# iteracion  80000
# error of My Linear Regression  0.3773580226426378
# iteracion  90000
# error of My Linear Regression  0.3699192883273651
# iteracion  100000
# error of My Linear Regression  0.3636355194740417
# iteracion  110000
# error of My Linear Regression  0.3583124400728243
# iteracion  120000
# error of My Linear Regression  0.35379000945902783
# iteracion  130000
# error of My Linear Regression  0.34993583470574463
# iteracion  140000
# error of My Linear Regression  0.3466400423309441
# iteracion  150000
# error of My Linear Regression  0.343811216618324
# iteracion  160000
# error of My Linear Regression  0.34137314165540283
# iteracion  170000
# error of My Linear Regression  0.3392621635939824
# iteracion  180000
# error of My Linear Regression  0.33742504042284427
# iteracion  190000
# error of My Linear Regression  0.33581718027941165
# iteracion  200000
# error of My Linear Regression  0.3344011925893002
# iteracion  210000
# error of My Linear Regression  0.3331456929447587
# iteracion  220000
# error of My Linear Regression  0.33202431489917916
# iteracion  230000
# error of My Linear Regression  0.3310148911575413
# iteracion  240000
# error of My Linear Regression  0.33009877385437814
# ------------- CROSS VALIDATION  3 ---------
# ------------- Random Forest ---------
# Error of Random Forest model:  0.23831681364231874
# ------------- XGBOOST ---------
# Error of XGBOOST model:  0.13443367785248309
# ------------- My Linear Regression ---------
# (1168, 75)
# iteracion  10000
# error of My Linear Regression  0.6137812847712121
# iteracion  20000
# error of My Linear Regression  0.5100996061893703
# iteracion  30000
# error of My Linear Regression  0.45739020535712044
# iteracion  40000
# error of My Linear Regression  0.4186825004024502
# iteracion  50000
# error of My Linear Regression  0.38925836643905576
# iteracion  60000
# error of My Linear Regression  0.36691340845644804
# iteracion  70000
# error of My Linear Regression  0.3500556619482345
# iteracion  80000
# error of My Linear Regression  0.3374510369994257
# iteracion  90000
# error of My Linear Regression  0.3281272172519846
# iteracion  100000
# error of My Linear Regression  0.3213163883841829
# iteracion  110000
# error of My Linear Regression  0.3164146816864474
# iteracion  120000
# error of My Linear Regression  0.31295040972645555
# iteracion  130000
# error of My Linear Regression  0.31055793437100754
# iteracion  140000
# error of My Linear Regression  0.3089559178229368
# iteracion  150000
# error of My Linear Regression  0.3079293651695921
# iteracion  160000
# error of My Linear Regression  0.30731501791976096
# iteracion  170000
# error of My Linear Regression  0.30698965687699975
# iteracion  180000
# error of My Linear Regression  0.3068608609736665
# iteracion  190000
# error of My Linear Regression  0.30685978477814335
# iteracion  200000
# error of My Linear Regression  0.3069355593888718
# iteracion  210000
# error of My Linear Regression  0.3070509772126138
# iteracion  220000
# error of My Linear Regression  0.3071791798069642
# iteracion  230000
# error of My Linear Regression  0.30730112269371845
# iteracion  240000
# error of My Linear Regression  0.307403638545603
# ------------- CROSS VALIDATION  4 ---------
# ------------- Random Forest ---------
# Error of Random Forest model:  0.24434067026535697
# ------------- XGBOOST ---------
# Error of XGBOOST model:  0.1199468764698094
# ------------- My Linear Regression ---------
# (1168, 75)
# iteracion  10000
# error of My Linear Regression  0.5562977448665909
# iteracion  20000
# error of My Linear Regression  0.46492782055558063
# iteracion  30000
# error of My Linear Regression  0.4141906839161223
# iteracion  40000
# error of My Linear Regression  0.37779351154269375
# iteracion  50000
# error of My Linear Regression  0.3514251361975828
# iteracion  60000
# error of My Linear Regression  0.3326081485145726
# iteracion  70000
# error of My Linear Regression  0.3194817940080375
# iteracion  80000
# error of My Linear Regression  0.31059876719219975
# iteracion  90000
# error of My Linear Regression  0.3048338279966869
# iteracion  100000
# error of My Linear Regression  0.30132207501823643
# iteracion  110000
# error of My Linear Regression  0.29940854239211523
# iteracion  120000
# error of My Linear Regression  0.29860454465384184
# iteracion  130000
# error of My Linear Regression  0.2985503436265539
# iteracion  140000
# error of My Linear Regression  0.29898431562876776
# iteracion  150000
# error of My Linear Regression  0.29971836059315804
# iteracion  160000
# error of My Linear Regression  0.3006188365193168
# iteracion  170000
# error of My Linear Regression  0.30159208424688444
# iteracion  180000
# error of My Linear Regression  0.30257359796234834
# iteracion  190000
# error of My Linear Regression  0.3035200034985276
# iteracion  200000
# error of My Linear Regression  0.30440315519284156
# iteracion  210000
# error of My Linear Regression  0.30520581019105164
# iteracion  220000
# error of My Linear Regression  0.305918467667554
# iteracion  230000
# error of My Linear Regression  0.3065370642216971
# iteracion  240000
# error of My Linear Regression  0.3070612969906247
# ------------- CROSS VALIDATION  5 ---------
# ------------- Random Forest ---------
# Error of Random Forest model:  0.24016095125746556
# ------------- XGBOOST ---------
# Error of XGBOOST model:  0.1325602995074348
# ------------- My Linear Regression ---------
# (1168, 75)
# iteracion  10000
# error of My Linear Regression  0.5703053423884209
# iteracion  20000
# error of My Linear Regression  0.477188794928585
# iteracion  30000
# error of My Linear Regression  0.4287884952051474
# iteracion  40000
# error of My Linear Regression  0.3935822200723265
# iteracion  50000
# error of My Linear Regression  0.36731566126361587
# iteracion  60000
# error of My Linear Regression  0.34782589097819944
# iteracion  70000
# error of My Linear Regression  0.3335174406676773
# iteracion  80000
# error of My Linear Regression  0.32315257013059195
# iteracion  90000
# error of My Linear Regression  0.3157646824841055
# iteracion  100000
# error of My Linear Regression  0.3106021058571846
# iteracion  110000
# error of My Linear Regression  0.30708516830689386
# iteracion  120000
# error of My Linear Regression  0.3047710552065438
# iteracion  130000
# error of My Linear Regression  0.303324581195814
# iteracion  140000
# error of My Linear Regression  0.3024941437555702
# iteracion  150000
# error of My Linear Regression  0.30209232155834187
# iteracion  160000
# error of My Linear Regression  0.3019805232902167
# iteracion  170000
# error of My Linear Regression  0.30205703949324375
# iteracion  180000
# error of My Linear Regression  0.3022478605264376
# iteracion  190000
# error of My Linear Regression  0.3024996856651021
# iteracion  200000
# error of My Linear Regression  0.30277463524915865
# iteracion  210000
# error of My Linear Regression  0.3030462688871511
# iteracion  220000
# error of My Linear Regression  0.3032965961654668
# iteracion  230000
# error of My Linear Regression  0.30351383711903696
# iteracion  240000
# error of My Linear Regression  0.3036907470330675

# %% [markdown]
# ## Best Results of the models

# %% [markdown]
# ### Minimal Error of each Model
# Random forest = 0.23831681364231874
#
# XGBOOST = 0.11932953018380113
#
# My Linear Regression = 0.2847561299685771

# %%
testData.insert(0, "bias", 1) 
sampleSubmission = pd.DataFrame(columns=['Id','SalePrice'])
sampleSubmission.shape
# Out:
# (0, 2)

# %%
global mrlWeight
mrlWeight
# Out:
# array([[ 0.65432514],
#        [ 1.14209803],
#        [ 1.69943535],
#        [ 1.74631349],
#        [ 2.33073314],
#        [ 0.3890098 ],
#        [ 0.98677138],
#        [ 1.88372772],
#        [ 1.43670437],
#        [ 0.94573551],
#        [ 1.80096102],
#        [ 1.76593583],
#        [ 1.91305455],
#        [ 0.56738284],
#        [ 0.33341841],
#        [ 0.82964978],
#        [ 1.85104906],
#        [ 1.88469351],
#        [12.92963285],
#        [12.13918323],
#        [ 0.74566809],
#        [ 0.82354002],
#        [ 1.46634661],
#        [ 0.22772662],
#        [ 0.49021342],
#        [ 3.00607859],
#        [ 1.48287797],
#        [ 0.52352246],
#        [ 0.61125229],
#        [ 0.15048183],
#        [ 0.67714389],
#        [ 1.71034341],
#        [ 0.93911448],
#        [ 4.73115426],
#        [ 1.90717018],
#        [ 0.52636509],
#        [ 5.83123747],
#        [ 9.21774587],
#        [ 1.7368502 ],
#        [ 1.98019953],
#        [ 0.97146429],
#        [ 1.10417873],
#        [ 9.62184866],
#        [ 4.2979167 ],
#        [ 0.67551921],
#        [13.29209779],
#        [ 1.78516833],
#        [ 1.58943667],
#        [ 0.89336937],
#        [ 1.95920627],
#        [ 0.14767043],
#        [ 0.22401478],
#        [ 0.32521376],
#        [ 0.14877157],
#        [ 1.1165331 ],
#        [ 0.04393177],
#        [ 0.71334904],
#        [12.48238841],
#        [ 1.65332613],
#        [ 0.3394564 ],
#        [ 5.41811592],
#        [ 0.2893512 ],
#        [ 1.05773699],
#        [ 0.51564035],
#        [ 2.16786399],
#        [ 0.52549711],
#        [ 1.57226956],
#        [ 0.25848254],
#        [ 2.04649438],
#        [ 1.91685641],
#        [ 1.51754308],
#        [ 1.78140163],
#        [12.56869446],
#        [ 0.73547394],
#        [ 1.04687551]])

# %%
testData.shape
npTestData = testData.values
npTestData
# Out:
# array([[1.000e+00, 2.000e+01, 2.000e+00, ..., 2.010e+03, 8.000e+00,
#         4.000e+00],
#        [1.000e+00, 2.000e+01, 3.000e+00, ..., 2.010e+03, 8.000e+00,
#         4.000e+00],
#        [1.000e+00, 6.000e+01, 3.000e+00, ..., 2.010e+03, 8.000e+00,
#         4.000e+00],
#        ...,
#        [1.000e+00, 2.000e+01, 3.000e+00, ..., 2.006e+03, 8.000e+00,
#         0.000e+00],
#        [1.000e+00, 8.500e+01, 3.000e+00, ..., 2.006e+03, 8.000e+00,
#         4.000e+00],
#        [1.000e+00, 6.000e+01, 3.000e+00, ..., 2.006e+03, 8.000e+00,
#         4.000e+00]])

# %% [markdown]
# ## Get Predicts of My Linear Regression

# %%
PredictTest = np.matmul(npTestData,mrlWeight)

# %%
np.savetxt("PredictTest.csv", PredictTest, delimiter=",")
